# %%
#merging vacant data with prevoiously merged dataset
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec 
from scipy import stats

# %%
df=pd.read_csv("mergeddf1.csv")
df
# Out:
#       property_key contractDate  year  month  quarter Data Series      price  \
# 0      p-c1ce31019     3/1/2018  2018      3        1    2018 1Q   1850000.0
# 1      p-a7fd7deb5     3/1/2018  2018      3        1    2018 1Q   1030000.0
# 2      p-2a981615e     3/1/2018  2018      3        1    2018 1Q   4300000.0
# 3      p-2bb570b5d     3/1/2018  2018      3        1    2018 1Q   1400888.0
# 4      p-4ccd6e1db     3/1/2018  2018      3        1    2018 1Q    725000.0
# ...            ...          ...   ...    ...      ...         ...        ...
# 62944  p-bd1f74cf3    12/1/2022  2022     12        4    2022 4Q   4630000.0
# 62945  p-bf14f1df6    12/1/2022  2022     12        4    2022 4Q   1500000.0
# 62946  p-d32689720    12/1/2022  2022     12        4    2022 4Q   1460000.0
# 62947  p-1475e4b20    12/1/2022  2022     12        4    2022 4Q   1390000.0
# 62948  p-7424f0b63    12/1/2022  2022     12        4    2022 4Q    880000.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62949 entries, 0 to 62948
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   property_key           62949 non-null  object
#  1   contractDate           62949 non-null  object
#  2   year                   62949 non-null  int64
#  3   month                  62949 non-null  int64
#  4   quarter                62949 non-null  int64
#  5   Data Series            62949 non-null  object
#  6   price                  62949 non-null  float64
#  7   area                   62949 non-null  float64
#  8   floorRange             62949 non-null  object
#  9   propertyType           62949 non-null  object
#  10  district               62949 non-null  int64
#  11  typeOfArea             62949 non-null  object
#  12  tenure                 62949 non-null  object
#  13  street                 62949 non-null  object
# ...

# %%
datetime, years, months = convert_dataseries_datetime(mergeddf1)
mergeddf1['contractDate'] = datetime
mergeddf1['year'] = years
mergeddf1['month']= months
mergeddf1.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8964\1487939229.py in <module>
# ----> 1 datetime, years, months = convert_dataseries_datetime(mergeddf1)
#       2 mergeddf1['contractDate'] = datetime
#       3 mergeddf1['year'] = years
#       4 mergeddf1['month']= months
#       5 mergeddf1.info()
#
# NameError: name 'convert_dataseries_datetime' is not defined

# %%
sns.lineplot( df['tenure'], df['price'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='tenure', ylabel='price'>

# %%
sns.boxplot(df['price'], df['tenure'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price', ylabel='tenure'>

# %%
fig, ax=plt.subplots(figsize=(15, 7))
ax.set_title('1. Bar distribution of price for year')
sns.barplot(x='price',y='year',data=df, color='c', ax=ax)
fig, ax=plt.subplots(figsize=(15, 7))
ax.set_title('2. Scatter distribution of price for year')
sns.swarmplot(x='price', y='year',hue='street',palette='Blues_r', data=df, ax=ax)
sns.lmplot(x='price', y='year',hue='street',palette='Blues_r', data=df, aspect=2.5);

# %%
plt.scatter(df['price'],df['year'])

# %% [markdown]
# ## here notice that from 2018 the housing price gradually decrase but in 2021 increase after that it agian decrase

# %%
sns.pairplot(df)

# %%
bx=sns.boxplot(df['floorRange'],df['price'])
plt.setp(bx.get_xticklabels(), rotation = 45)
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.set_title('Distribution of price for street')
sns.barplot(x='price',y='street',palette='Blues_r', data=df, ax=ax)
# Out:
# <AxesSubplot:title={'center':'Distribution of price for street'}, xlabel='price', ylabel='street'>

# %%
sns.scatter(x='street',y='price',data=df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13112\1661318174.py in <module>
# ----> 1 sns.scatter(x='street',y='price',data=df)
#
# AttributeError: module 'seaborn' has no attribute 'scatter'
